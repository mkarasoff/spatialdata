# %%
import pandas as pd

fileName=r'C:\Users\mike\Documents\ArcGIS\Projects\Assignements\week5\peerGradeW5\week5_data\covid\daily.csv'
index_col=['date', 'state']

# %%
df = pd.read_csv(fileName, index_col=index_col)
df.sort_index()
df
# Out:
#                 positive  negative  pending  hospitalizedCurrently  \
# date     state
# 20200501 AK        364.0   19961.0      NaN                   25.0
#          AL       7158.0   84775.0      NaN                    NaN
#          AR       3321.0   46355.0      NaN                   95.0
#          AS          0.0      57.0      NaN                    NaN
#          AZ       7962.0   66917.0      NaN                  709.0
# ...                  ...       ...      ...                    ...
# 20200126 WA          1.0       NaN      NaN                    NaN
# 20200125 WA          1.0       NaN      NaN                    NaN
# 20200124 WA          1.0       NaN      NaN                    NaN
# 20200123 WA          1.0       NaN      NaN                    NaN
# 20200122 WA          1.0       NaN      NaN                    NaN
#
#                 hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date     state
# ...

# %%
df.loc[20200423].to_csv(r'C:\Users\mike\Documents\ArcGIS\Projects\Assignements\week5\peerGradeW5\week5_data\covid\daily_20200423.csv')

# %%
df.loc[20200410].to_csv(r'C:\Users\mike\Documents\ArcGIS\Projects\Assignements\week5\peerGradeW5\week5_data\covid\daily_20200410.csv')
